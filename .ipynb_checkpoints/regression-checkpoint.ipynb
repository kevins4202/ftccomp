# %%
import pandas as pd
import numpy as np
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource
import csv
from bokeh.io import output_notebook
import os
# Regression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
output_notebook()
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="a1e12e0e-8c4d-45bb-a414-f45ba9bf2e07">Loading BokehJS ...</span>
#     </div>

# %%
sorted(os.listdir(os.getcwd() + '/scripts'))
# Out:
# ['.ipynb_checkpoints',
#  'Untitled.ipynb',
#  'generate_team_data.ipynb',
#  'get_all_data.ipynb',
#  'matches-AUCAQ.txt',
#  'matches-AUCMP.txt',
#  'matches-AUPYQ.txt',
#  'matches-AUTOQ.txt',
#  'matches-AUWOQ.txt',
#  'matches-BRBHS.txt',
#  'matches-BRCMP.txt',
#  'matches-CAABABNALT.txt',
#  'matches-CAABABNAM1.txt',
#  'matches-CAABABNAM2.txt',
#  'matches-CAABABNAM3.txt',
#  'matches-CAABABNAM4.txt',
#  'matches-CAABABSALTDOW.txt',
#  'matches-CAABABSALTFIN.txt',
#  'matches-CAABABSAM1A.txt',
#  'matches-CAABABSAM1B.txt',
#  'matches-CAABABSAM2.txt',
#  'matches-CAABABSAM3.txt',
#  'matches-CAABABSAM4.txt',
#  'matches-CAABCMP.txt',
#  'matches-CABCCMP.txt',
#  'matches-CABCKIS.txt',
#  'matches-CABCKIS6.txt',
#  'matches-CABCSUQ.txt',
#  'matches-CABCSUS.txt',
#  'matches-CABCVAS.txt',
#  'matches-CABCVAS2.txt',
#  'matches-CABCVAS3.txt',
#  'matches-CABCVIQ.txt',
#  'matches-CAONAUQ.txt',
#  'matches-CAONBOQ.txt',
#  'matches-CAONCMP.txt',
#  'matches-CAONKIQ.txt',
# ...

# %%
df = pd.DataFrame(columns = ['team11', 'team12', 'full1', 'auto1', 'team21', 'team22', 'full2', 'auto2'])

# %%
with open(os.getcwd() + '/scripts/scores.csv', 'w') as out_file:
    writer = csv.writer(out_file)
    writer.writerow(('OPR1', 'Auto1', 'CCWM1', 'OPR2', 'Auto2', 'CCWM2', 'OPR3', 'Auto3', 'CCWM3', 'OPR4', 'Auto4', 'CCWM4','score1', 'auto1', 'score2', 'auto2'))
for d in os.listdir(os.getcwd() + '/scripts'):
    print(d)
    if 'matches-' in d:
        with open(os.getcwd() + '/scripts/'+d, 'r') as in_file:
            stripped = (line.strip() for line in in_file)
            lines = (line.split(" ") for line in stripped if line)
            with open(os.getcwd() + '/scripts/scores.csv', 'a') as out_file:
                writer = csv.writer(out_file)
                writer.writerows([list(l)[2:4]+list(l)[6:8] for l in lines])
# Out:
# .ipynb_checkpoints
# generate_team_data.ipynb
# get_all_data.ipynb
# matches-AUCAQ.txt
# matches-AUCMP.txt
# matches-AUPYQ.txt
# matches-AUTOQ.txt
# matches-AUWOQ.txt
# matches-BRBHS.txt
# matches-BRCMP.txt
# matches-CAABABNALT.txt
# matches-CAABABNAM1.txt
# matches-CAABABNAM2.txt
# matches-CAABABNAM3.txt
# matches-CAABABNAM4.txt
# matches-CAABABSALTDOW.txt
# matches-CAABABSALTFIN.txt
# matches-CAABABSAM1A.txt
# matches-CAABABSAM1B.txt
# matches-CAABABSAM2.txt
# matches-CAABABSAM3.txt
# matches-CAABABSAM4.txt
# matches-CAABCMP.txt
# matches-CABCCMP.txt
# matches-CABCKIS.txt
# matches-CABCKIS6.txt
# matches-CABCSUQ.txt
# matches-CABCSUS.txt
# matches-CABCVAS.txt
# matches-CABCVAS2.txt
# matches-CABCVAS3.txt
# matches-CABCVIQ.txt
# matches-CAONAUQ.txt
# matches-CAONBOQ.txt
# matches-CAONCMP.txt
# matches-CAONKIQ.txt
# matches-CAONSCQ.txt
# matches-CAONSCQ2.txt
# matches-CAONSUQ.txt
# matches-CAONWIQ.txt
# matches-CAQCCMP.txt
# matches-CNDIS.txt
# matches-CYCMP.txt
# ...
