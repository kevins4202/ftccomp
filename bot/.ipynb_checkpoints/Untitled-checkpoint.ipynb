# %%
import os
import discord
from dotenv import load_dotenv

# %%
bot = discord.Client()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 bot = discord.Client()
#
# TypeError: __init__() missing 1 required keyword-only argument: 'intents'
