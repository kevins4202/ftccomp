# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os

# %%
token = 'F370ADBF-DC4B-4364-807E-F56673B369BC'

# %%
url = 'https://ftc-events.firstinspires.org/2022'

# %%
text = requests.get(url, auth = ('szj2024', token)
                    , params = {'teamNumber':15118}
                   )

# %%
print(text.text)
# Out:
# {"matches":[]}

# %%
matchurl = 'http://ftc-api.firstinspires.org/v2.0/2022/matches/USILNEM1'

# %%
match_text = requests.get(matchurl, auth = ('szj2024', token)
                    , params = {'teamNumber':15118}
                   )

# %%
text = requests.get(url).text

# %%
text
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n<!--  PLEASE DO NOT SCRAPE WEBPAGES FOR EVENT DATA!\nWe have an API that allows easy access to event and team\ndata! It is easier for developers, and helps keep this server\navailable for the public who are seeking basic event information.\nMore info: https://ftc-events.firstinspires.org/services/API\n____ ____ ___   ____ ______\n/ __//  _// _ \\ / __//_  __/ (R)\n/ _/ _/ / / , _/_\\ \\   / /\n/_/  /___//_/|_|/___/  /_/\n\n-->\n<head>\n\t<title>\n\t\tFTC Event Web : Home\n\t</title>\n\t<meta name="description" content="Official source of event information, results and webcasts from the FIRST FIRST Tech Challenge "/>\n\t<link rel="stylesheet"\n\t\t  href="https://ftc-events-cdn.global-prod.ftclive.org/evtwebextFTC/app.48544bfc62deef954ddd.css" />\n\t\n\t<meta name="viewport" content="width=device-width, initial-scale=1,user-scalable=no" />\n\t<link rel="icon" type="image/x-icon" href="https://ftc-events-cdn.global-prod.ftclive.org/eventweb_common/fa
# ...

# %%
soup = BeautifulSoup(text.text, 'lxml')

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n <!--  PLEASE DO NOT SCRAPE WEBPAGES FOR EVENT DATA!\nWe have an API that allows easy access to event and team\ndata! It is easier for developers, and helps keep this server\navailable for the public who are seeking basic event information.\nMore info: https://ftc-events.firstinspires.org/services/API\n____ ____ ___   ____ ______\n/ __//  _// _ \\ / __//_  __/ (R)\n/ _/ _/ / / , _/_\\ \\   / /\n/_/  /___//_/|_|/___/  /_/\n\n-->\n <head>\n  <title>\n   FTC Event Web : Home\n  </title>\n  <meta content="Official source of event information, results and webcasts from the FIRST FIRST Tech Challenge " name="description"/>\n  <link href="https://ftc-events-cdn.global-prod.ftclive.org/evtwebextFTC/app.48544bfc62deef954ddd.css" rel="stylesheet"/>\n  <meta content="width=device-width, initial-scale=1,user-scalable=no" name="viewport"/>\n  <link href="https://ftc-events-cdn.global-prod.ftclive.org/eventweb_common/favicon/first.ico" rel="icon" type="image/x-i
# ...

# %%
mydivs = soup.find_all("div", {"class": "col-xs-4 col-lg-9"})

# %%
mydivs
# Out:
# []

# %%
import time
from bs4 import BeautifulSoup
from selenium import webdriver


url = "https://ftc-events.firstinspires.org/2022"
options = Options()
options.add_argument('--headless')
options.add_argument('--disable-gpu')
driver = webdriver.Safari()
driver.get(url)
time.sleep(3)
page = driver.page_source
driver.quit()
soup = BeautifulSoup(page, 'lxml')
container = soup.find_all('div', attrs={
    'class':'overflow-ellipsis'})
print(container)
# Out:
# [<div class="overflow-ellipsis"><a href="2022/USALCMP">Alabama State Championship</a></div>, <div class="overflow-ellipsis"><a href="2022/USAKCMP">Alaska State Championship</a></div>, <div class="overflow-ellipsis"><a href="2022/CAABCMP">Alberta Championship</a></div>, <div class="overflow-ellipsis"><a href="2022/USAZCMP">Arizona FIRST Tech Challenge Championship</a></div>, <div class="overflow-ellipsis"><a href="2022/USARCMP">Arkansas Championship</a></div>, <div class="overflow-ellipsis"><a href="2022/AUCMP">Australian National Championship</a></div>, <div class="overflow-ellipsis"><a href="2022/BRCMP">Brazil FTC National Tournament</a></div>, <div class="overflow-ellipsis"><a href="2022/CABCCMP">British Columbia Championship</a></div>, <div class="overflow-ellipsis"><a href="2022/USCASDCMP">CA- San Diego Regional Championship</a></div>, <div class="overflow-ellipsis"><a href="2022/USCALACMP">California SoCal Championship</a></div>, <div class="overflow-ellipsis"><a href="2022/USCA
# ...

# %%
for c in container:
    a_tag = c.find_all("a")
    for tag in a_tag:
        print(tag.text)
        print(tag['href'])
# Out:
# Alabama State Championship
# 2022/USALCMP
# Alaska State Championship
# 2022/USAKCMP
# Alberta Championship
# 2022/CAABCMP
# Arizona FIRST Tech Challenge Championship
# 2022/USAZCMP
# Arkansas Championship
# 2022/USARCMP
# Australian National Championship
# 2022/AUCMP
# Brazil FTC National Tournament
# 2022/BRCMP
# British Columbia Championship
# 2022/CABCCMP
# CA- San Diego Regional Championship
# 2022/USCASDCMP
# California SoCal Championship
# 2022/USCALACMP
# California-NorCal FTC Regional Championship
# 2022/USCANOCMP
# CALS Los Angeles Unified School District Regional Championship
# 2022/USCALSCMP
# Chesapeake FTC Championship
# 2022/USCHSCMP
# China FTC Championship
# 2022/CNCMP
# Colorado State Championship 2022-2023
# 2022/USCOCMP
# Connecticut State Championship
# 2022/USCTCMP
# Cyprus FTC Championship 2023
# 2022/CYCMP
# Delaware 2022-2023 FTC Championship
# 2022/USDECMP
# Festival de Robotique - Championnat provincial du Défi Techno FIRST
# 2022/CAQCCMP
# ...
