# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os

# %%
token = 'F370ADBF-DC4B-4364-807E-F56673B369BC'

# %%
url = 'http://ftc-api.firstinspires.org/v2.0/2022/teams'

# %%
text = requests.get(url, auth = ('szj2024', token)
                    , params = {'teamNumber':1}
                   )

# %%
print(text.text)
# Out:
# {"teams":[{"teamNumber":1,"nameFull":"PTC & FTC1 Team Unlimited 4-H Club","nameShort":"Team Unlimited","schoolName":null,"city":"Sharon","stateProv":"MA","country":"USA","website":"http://www.ftc0001.org/","rookieYear":2007,"robotName":null,"districtCode":null,"homeCMP":null}],"teamCountTotal":1,"teamCountPage":1,"pageCurrent":1,"pageTotal":1}

# %%
matchurl = 'http://ftc-api.firstinspires.org/v2.0/2022/matches/USILNEM1'

# %%
match_text = requests.get(matchurl, auth = ('szj2024', token)
                    , params = {'teamNumber':15118}
                   )

# %%
text.text
# Out:
# '{"teams":[{"teamNumber":15118,"nameFull":"Deerfield High School","nameShort":"CogChamp","schoolName":null,"city":"Deerfield","stateProv":"IL","country":"USA","website":null,"rookieYear":2018,"robotName":null,"districtCode":null,"homeCMP":null}],"teamCountTotal":1,"teamCountPage":1,"pageCurrent":1,"pageTotal":1}'
